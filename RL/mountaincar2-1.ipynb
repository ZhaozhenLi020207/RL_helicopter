# %%
import sympy
from sympy import symbols,Eq
from IPython.display import display

sympy.init_printing(use_latex=True)

# %%
v_hungry, v_full = symbols('v_hungry v_full')
q_hungry_eat, q_hungry_none, q_full_eat, q_full_none = \
        symbols('q_hungry_eat q_hungry_none q_full_eat q_full_none')
alpha, beta, gamma = symbols('alpha beta gamma')
x, y = symbols('x y')

# %%
system = sympy.Matrix((
        (1, 0, x-1, -x, 0, 0, 0),
        (0, 1, 0, 0, -y, y-1, 0),
        (-gamma, 0, 1, 0, 0, 0, -2),
        ((alpha-1)*gamma, -alpha*gamma, 0, 1, 0, 0, 4*alpha-3),
        (-beta*gamma, (beta-1)*gamma, 0, 0, 1, 0, -4*beta+2),
        (0, -gamma, 0, 0, 0, 1, 1) ))
solution = sympy.solve_linear_system(system,
        v_hungry, v_full,
        q_hungry_none, q_hungry_eat, q_full_none, q_full_eat)

# %%
# 第五步：兼容式显示结果（同时支持print和display）
if solution is not None:
    print("\n=== 美观格式输出 ===")
    for var, expr in solution.items():
        # 方式1：display渲染LaTeX公式
        display((var, expr))
# Out:
# === 美观格式输出 ===
# ⎛          -α⋅γ⋅x⋅y + 3⋅α⋅γ⋅x - 4⋅α⋅x + β⋅γ⋅x⋅y + 2⋅β⋅γ⋅y - γ⋅x - 2⋅γ + x + 2⎞
# ⎜v_hungry, ──────────────────────────────────────────────────────────────────⎟
# ⎜                       2                2              2                    ⎟
# ⎝                    α⋅γ ⋅x - α⋅γ⋅x + β⋅γ ⋅y - β⋅γ⋅y - γ  + 2⋅γ - 1          ⎠
# ⎛        -α⋅γ⋅x⋅y - α⋅γ⋅x + β⋅γ⋅x⋅y - 2⋅β⋅γ⋅y + 4⋅β⋅y + γ⋅y + γ - y - 1⎞
# ⎜v_full, ──────────────────────────────────────────────────────────────⎟
# ⎜                   2                2              2                  ⎟
# ⎝                α⋅γ ⋅x - α⋅γ⋅x + β⋅γ ⋅y - β⋅γ⋅y - γ  + 2⋅γ - 1        ⎠
# ⎛                    2          2                  2                  2        ↪
# ⎜               - α⋅γ ⋅x⋅y + α⋅γ ⋅x - 2⋅α⋅γ⋅x + β⋅γ ⋅x⋅y + 2⋅β⋅γ⋅y - γ ⋅x + γ⋅ ↪
# ⎜q_hungry_none, ────────────────────────────────────────────────────────────── ↪
# ⎜                               2                2              2              ↪
# ⎝                            α⋅γ ⋅x - α⋅γ⋅x + β⋅γ ⋅y - β⋅γ⋅y - γ  + 2⋅γ - 1    ↪
#
# ↪            ⎞
# ↪ x - 2⋅γ + 2⎟
# ↪ ───────────⎟
# ↪            ⎟
# ↪            ⎠
# ⎛                   2          2        2        2                             ↪
# ⎜              - α⋅γ ⋅x⋅y + α⋅γ ⋅x + α⋅γ ⋅y - α⋅γ  - 2⋅α⋅γ⋅x - α⋅γ⋅y + 5⋅α⋅γ - ↪
# ⎜q_hungry_eat, ─────────────────────────────────────────────────────────────── ↪
# ⎜                                                        2                2    ↪
# ⎝                                                     α⋅γ ⋅x - α⋅γ⋅x + β⋅γ ⋅y  ↪
#
# ↪           2          2                2      2                ⎞
# ↪  4⋅α + β⋅γ ⋅x⋅y - β⋅γ ⋅y + 3⋅β⋅γ⋅y - γ ⋅x + γ  + γ⋅x - 4⋅γ + 3⎟
# ↪ ──────────────────────────────────────────────────────────────⎟
# ↪            2                                                  ⎟
# ↪ - β⋅γ⋅y - γ  + 2⋅γ - 1                                        ⎠
# ⎛                  2          2                  2          2        2         ↪
# ⎜             - α⋅γ ⋅x⋅y + α⋅γ ⋅x - 2⋅α⋅γ⋅x + β⋅γ ⋅x⋅y - β⋅γ ⋅x - β⋅γ ⋅y + β⋅γ ↪
# ⎜q_full_none, ──────────────────────────────────────────────────────────────── ↪
# ⎜                                                       2                2     ↪
# ⎝                                                    α⋅γ ⋅x - α⋅γ⋅x + β⋅γ ⋅y - ↪
#
# ↪ 2                                    2      2                ⎞
# ↪   + β⋅γ⋅x + 3⋅β⋅γ⋅y - 5⋅β⋅γ + 4⋅β + γ ⋅y - γ  - γ⋅y + 3⋅γ - 2⎟
# ↪ ─────────────────────────────────────────────────────────────⎟
# ↪           2                                                  ⎟
# ↪  β⋅γ⋅y - γ  + 2⋅γ - 1                                        ⎠
# ⎛                 2                  2          2                2             ↪
# ⎜            - α⋅γ ⋅x⋅y - α⋅γ⋅x + β⋅γ ⋅x⋅y - β⋅γ ⋅y + 3⋅β⋅γ⋅y + γ ⋅y - γ⋅y + γ ↪
# ⎜q_full_eat, ───────────────────────────────────────────────────────────────── ↪
# ⎜                          2                2              2                   ↪
# ⎝                       α⋅γ ⋅x - α⋅γ⋅x + β⋅γ ⋅y - β⋅γ⋅y - γ  + 2⋅γ - 1         ↪
#
# ↪     ⎞
# ↪  - 1⎟
# ↪ ────⎟
# ↪     ⎟
# ↪     ⎠
