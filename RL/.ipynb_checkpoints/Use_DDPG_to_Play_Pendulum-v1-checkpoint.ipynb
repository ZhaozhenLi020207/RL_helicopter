# %%
# %matplotlib inline

import sys
import logging
import itertools
import copy

import numpy as np
np.random.seed(0)
import pandas as pd
import gymnasium as gym
import matplotlib.pyplot as plt
import torch
torch.manual_seed(0)
import torch.nn as nn
import torch.optim as optim

logging.basicConfig(level=logging.INFO,
        format='%(asctime)s [%(levelname)s] %(message)s',
        stream=sys.stdout, datefmt='%H:%M:%S')

# %%
env = gym.make('Pendulum-v1')
for key in vars(env.spec):
    logging.info('%s: %s', key, vars(env.spec)[key])
for key in vars(env.unwrapped):
    logging.info('%s: %s', key, vars(env.unwrapped)[key])
# Out:
# 17:03:06 [INFO] id: Pendulum-v1
# 17:03:06 [INFO] entry_point: gymnasium.envs.classic_control.pendulum:PendulumEnv
# 17:03:06 [INFO] reward_threshold: None
# 17:03:06 [INFO] nondeterministic: False
# 17:03:06 [INFO] max_episode_steps: 200
# 17:03:06 [INFO] order_enforce: True
# 17:03:06 [INFO] disable_env_checker: False
# 17:03:06 [INFO] kwargs: {}
# 17:03:06 [INFO] additional_wrappers: ()
# 17:03:06 [INFO] vector_entry_point: None
# 17:03:06 [INFO] namespace: None
# 17:03:06 [INFO] name: Pendulum
# 17:03:06 [INFO] version: 1
# 17:03:06 [INFO] max_speed: 8
# 17:03:06 [INFO] max_torque: 2.0
# 17:03:06 [INFO] dt: 0.05
# 17:03:06 [INFO] g: 10.0
# 17:03:06 [INFO] m: 1.0
# 17:03:06 [INFO] l: 1.0
# 17:03:06 [INFO] render_mode: None
# 17:03:06 [INFO] screen_dim: 500
# 17:03:06 [INFO] screen: None
# 17:03:06 [INFO] clock: None
# 17:03:06 [INFO] isopen: True
# 17:03:06 [INFO] action_space: Box(-2.0, 2.0, (1,), float32)
# 17:03:06 [INFO] observation_space: Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)
# 17:03:06 [INFO] spec: EnvSpec(id='Pendulum-v1', entry_point='gymnasium.envs.classic_control.pendulum:PendulumEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=None, order_enforce=False, disable_env_checker=True, kwargs={}, namespace=None, name='Pendulum', version=1, additional_wrappers=(), vector_entry_point=None)

# %%
#经验回放池
class DQNReplayer:
    def __init__(self, capacity):
        #用DataFrame存储经验，索引范围是[0, capacity-1]，列对应经验的5个核心字段
        self.memory = pd.DataFrame(index=range(capacity),
                columns=['observation', 'action', 'reward',
                'next_observation', 'terminated'])
        #记录当前要写入的位置（指针）
        self.i = 0
        #记录已存储的经验总数（不会超过capacity）
        self.count = 0
        #回放池的最大容量
        self.capacity = capacity
    #存储单条经验
    def store(self, *args):
        #将传入的经验参数（obs, act, rew, next_obs, terminated）转为数组，存入当前指针位置
        self.memory.loc[self.i] = np.asarray(args, dtype=object)
        #指针后移一位，超过容量则循环到0
        self.i = (self.i + 1) % self.capacity
        #经验数+1，最多不超过容量
        self.count = min(self.count + 1, self.capacity)
    #随机采样批量经验
    def sample(self, size):
        #从已存储的count条经验中，随机选size个索引（无放回采样）
        indices = np.random.choice(self.count, size=size)
        #按列提取采样的经验，转为数组并返回（返回5个数组，对应5个字段）
        return (np.stack(self.memory.loc[indices, field]) for field in
                self.memory.columns)

# %%
#OU噪声
class OrnsteinUhlenbeckProcess:
    def __init__(self, x0):
        self.x = x0 #噪声的初始值（通常是全0数组，维度和动作维度一致）
    #mu噪声的均值 sigma波动率 theta回归系数 dt时间步长
    def __call__(self, mu=0., sigma=1., theta=.15, dt=.01):
        # 生成标准正态分布的随机数（维度和self.x一致）
        n = np.random.normal(size=self.x.shape)
        # OU过程的核心更新公式
        self.x += (theta * (mu - self.x) * dt + sigma * np.sqrt(dt) * n)
        #返回更新后的噪声值
        return self.x

# %%
class DDPGAgent:
    def __init__(self, env):
        state_dim = env.observation_space.shape[0] #状态维度
        self.action_dim = env.action_space.shape[0] #动作维度
        self.action_low = env.action_space.low[0] #动作最小值
        self.action_high = env.action_space.high[0] #动作最大值
        self.gamma = 0.99 #折扣因子

        self.replayer = DQNReplayer(20000) #经验回放池
#Actor网络（策略网络）
        self.actor_evaluate_net = self.build_net(
                input_size=state_dim, hidden_sizes=[32, 64],
                output_size=self.action_dim)
        self.actor_optimizer = optim.Adam(self.actor_evaluate_net.parameters(),
                lr=0.0001) #优化器
        self.actor_target_net = copy.deepcopy(self.actor_evaluate_net) #目标网
#Critic网络（价值网络） 输入状态+动作 输出动作的价值
        self.critic_evaluate_net = self.build_net(
                input_size=state_dim+self.action_dim, hidden_sizes=[64, 128])
        self.critic_optimizer = optim.Adam(self.critic_evaluate_net.parameters(),
                lr=0.001)
        self.critic_loss = nn.MSELoss() #损失函数：均方误差
        self.critic_target_net = copy.deepcopy(self.critic_evaluate_net) #目标网

    def build_net(self, input_size, hidden_sizes, output_size=1, 
            output_activator=None): #构建全连接神经网络
        layers = []
        #依次构建线性层+ReLU激活(隐藏层)
        for input_size, output_size in zip(
                [input_size,] + hidden_sizes, hidden_sizes + [output_size,]):
            layers.append(nn.Linear(input_size, output_size)) #线性层（特征映射）
            layers.append(nn.ReLU()) #非线性激活（增加表达能力）
        layers = layers[:-1] #去掉最后一个ReLU（避免输出被激活，比如动作/价值不需要ReLU截断）
        if output_activator:
            layers.append(output_activator) #可选输出激活
        net = nn.Sequential(*layers) #组装网络
        return net

    def reset(self, mode=None): #重置Agent状态（训练/测试模式切换）
        self.mode = mode
        if self.mode == 'train':
            self.trajectory = [] #存储轨迹
            #OU噪声：连续动作空间的探索噪声
            self.noise = OrnsteinUhlenbeckProcess(np.zeros((self.action_dim,)))
#核心交互逻辑（输入环境观测，输出动作）
    def step(self, observation, reward, terminated):
        #探索阶段：经验池样本不足时，纯随机动作（先收集足够经验）
        if self.mode == 'train' and self.replayer.count < 3000:
            action = np.random.uniform(self.action_low, self.action_high)
        #正常决策：用Actor评估网输出确定性动作
        else:
            state_tensor = torch.as_tensor(observation,
                    dtype=torch.float).reshape(1, -1)
            action_tensor = self.actor_evaluate_net(state_tensor)
            action = action_tensor.detach().numpy()[0]
        #训练模式下的额外操作：加噪声、存经验、触发学习
        if self.mode == 'train':
            # noisy action
            noise = self.noise(sigma=0.1) #加探索噪声
            action = (action + noise).clip(self.action_low, self.action_high) #裁剪到动作范围

            self.trajectory += [observation, reward, terminated, action] #存储轨迹
            #每收集2步经验（8个元素），存回回放池
            if len(self.trajectory) >= 8:
                state, _, _, act, next_state, reward, terminated, _ = \
                        self.trajectory[-8:]
                self.replayer.store(state, act, reward, next_state, terminated)
            #经验池足够时，触发学习
            if self.replayer.count >= 3000:
                self.learn()
        return action

    def close(self):
        pass
#软更新目标网络
    def update_net(self, target_net, evaluate_net, learning_rate=0.005):
        for target_param, evaluate_param in zip(
                target_net.parameters(), evaluate_net.parameters()):
            #目标网参数 = 学习率 * 评估网参数 + （1 - 学习率）* 目标网参数
            target_param.data.copy_(learning_rate * evaluate_param.data
                    + (1 - learning_rate) * target_param.data)
#DDPG核心，分两步更新Critic 和 Actor 
    def learn(self):
        # replay 从回放池采集批量经验（64条）
        states, actions, rewards, next_states, terminateds = \
                self.replayer.sample(64)
        #转tensor
        state_tensor = torch.as_tensor(states, dtype=torch.float)
        action_tensor = torch.as_tensor(actions, dtype=torch.float)
        reward_tensor = torch.as_tensor(rewards, dtype=torch.float)
        next_state_tensor = torch.as_tensor(next_states, dtype=torch.float)
        terminated_tensor = torch.as_tensor(terminateds, dtype=torch.float)

        # update critic 评估动作价值
        #用Actor目标网预测下一状态的动作，加少量噪声（探索）
        next_action_tensor = self.actor_target_net(next_state_tensor)
        noise_tensor = (0.2 * torch.randn_like(action_tensor, dtype=torch.float))
        noisy_next_action_tensor = (next_action_tensor + noise_tensor).clamp(
                self.action_low, self.action_high)
        #拼接下一状态+下一动作，用Critic目标网计算Q值
        next_state_action_tensor = torch.cat([next_state_tensor,
                noisy_next_action_tensor], 1)
        next_q_tensor = self.critic_target_net(next_state_action_tensor).squeeze(1)
        #贝尔曼方程： 目标Q值 = 即时奖励 + 折扣 * 未来Q值
        critic_target_tensor = reward_tensor + (1. - terminated_tensor) * \
                self.gamma * next_q_tensor
        critic_target_tensor = critic_target_tensor.detach() #固定目标网梯度
        #计算Critic预测Q值，求损失并更新
        state_action_tensor = torch.cat([state_tensor, action_tensor], 1)
        critic_pred_tensor = self.critic_evaluate_net(state_action_tensor
                ).squeeze(1)
        critic_loss_tensor = self.critic_loss(critic_pred_tensor,
                critic_target_tensor)
        self.critic_optimizer.zero_grad() #清空梯度
        critic_loss_tensor.backward() #反向传播
        self.critic_optimizer.step() #更新参数

        # update actor 优化策略，输出更优动作
        pred_action_tensor = self.actor_evaluate_net(state_tensor)
        pred_action_tensor = pred_action_tensor.clamp(self.action_low,
                self.action_high)
        #拼接 当前状态+预测动作，用Critic评估该动作的价值
        pred_state_action_tensor = torch.cat([state_tensor, pred_action_tensor], 1)
        critic_pred_tensor = self.critic_evaluate_net(pred_state_action_tensor)
        #Actor损失，负Q值均值（因为要最大化Q值，所以最小化-Q值）
        actor_loss_tensor = -critic_pred_tensor.mean()
        self.actor_optimizer.zero_grad()
        actor_loss_tensor.backward()
        self.actor_optimizer.step()
        #软更新目标网络
        self.update_net(self.critic_target_net, self.critic_evaluate_net)
        self.update_net(self.actor_target_net, self.actor_evaluate_net)


agent = DDPGAgent(env)

# %%
def play_episode(env, agent, seed=None, mode=None, render=False):
    #重置环境：获取初始观测（seed保证可复现）
    observation, _ = env.reset(seed=seed)
    #初始化奖励、终止标志（terminated=任务完成/失败，truncated=步数超限）
    reward, terminated, truncated = 0., False, False
    #重置Agent：传入训练/测试模式（比如训练模式加噪声，测试模式不加）
    agent.reset(mode=mode)
    #初始化该局的总奖励和步数
    episode_reward, elapsed_steps = 0., 0
    #单局交互循环（直到终止）
    while True:
        #Agent根据当前观测、上一步奖励、终止标志，输出动作
        action = agent.step(observation, reward, terminated)
        #可选渲染环境（比如显示游戏画面、机器人运动）
        if render:
            env.render()
        #若环境已终止，跳出循环
        if terminated or truncated:
            break
        #环境执行动作，返回新的观测、奖励、终止标志
        observation, reward, terminated, truncated, _ = env.step(action)
        #. 累计该局奖励和步数
        episode_reward += reward
        elapsed_steps += 1
    #关闭Agent（预留接口，比如释放资源）
    agent.close()
    #返回该局总奖励和步数
    return episode_reward, elapsed_steps


logging.info('==== train ====')
episode_rewards = [] ## 存储每局的奖励，用于监控训练进度
## itertools.count()：无限循环（直到满足终止条件）
for episode in itertools.count():
    # 运行一局训练（mode='train'，Agent会加噪声、收集经验、更新网络）
    episode_reward, elapsed_steps = play_episode(env, agent, seed=episode,
            mode='train')
    episode_rewards.append(episode_reward)
    # 打印训练日志（局数、奖励、步数)
    logging.info('train episode %d: reward = %.2f, steps = %d',
            episode, episode_reward, elapsed_steps)
    # 打印训练日志（局数、奖励、步数
    if np.mean(episode_rewards[-10:]) > -120:
        break
# 绘制奖励变化曲线（直观查看训练趋势)
plt.plot(episode_rewards)


logging.info('==== test ====')
episode_rewards = []
for episode in range(100):
    episode_reward, elapsed_steps = play_episode(env, agent)
    episode_rewards.append(episode_reward)
    logging.info('test episode %d: reward = %.2f, steps = %d',
            episode, episode_reward, elapsed_steps)
# 输出统计结果：平均奖励 ± 标准差（衡量性能和稳定性）
logging.info('average episode reward = %.2f ± %.2f',
        np.mean(episode_rewards), np.std(episode_rewards))
# Out:
# 17:03:49 [INFO] ==== train ====
# 17:03:49 [INFO] train episode 0: reward = -978.58, steps = 200
# 17:03:49 [INFO] train episode 1: reward = -978.48, steps = 200
# 17:03:49 [INFO] train episode 2: reward = -1120.99, steps = 200
# 17:03:49 [INFO] train episode 3: reward = -1463.17, steps = 200
# 17:03:49 [INFO] train episode 4: reward = -1641.70, steps = 200
# 17:03:49 [INFO] train episode 5: reward = -1457.94, steps = 200
# 17:03:49 [INFO] train episode 6: reward = -860.93, steps = 200
# 17:03:49 [INFO] train episode 7: reward = -1145.15, steps = 200
# 17:03:49 [INFO] train episode 8: reward = -922.51, steps = 200
# 17:03:49 [INFO] train episode 9: reward = -1604.65, steps = 200
# 17:03:49 [INFO] train episode 10: reward = -1675.24, steps = 200
# 17:03:49 [INFO] train episode 11: reward = -1514.80, steps = 200
# 17:03:49 [INFO] train episode 12: reward = -1297.64, steps = 200
# 17:03:50 [INFO] train episode 13: reward = -1400.94, steps = 200
# 17:03:50 [INFO] train episode 14: reward = -1410.17, steps = 200
# 17:03:51 [INFO] train episode 15: reward = -1152.92, steps = 200
# 17:03:53 [INFO] train episode 16: reward = -1086.08, steps = 200
# 17:03:54 [INFO] train episode 17: reward = -1798.49, steps = 200
# 17:03:56 [INFO] train episode 18: reward = -1638.22, steps = 200
# 17:03:57 [INFO] train episode 19: reward = -1416.66, steps = 200
# 17:03:58 [INFO] train episode 20: reward = -1477.70, steps = 200
# 17:04:00 [INFO] train episode 21: reward = -1483.74, steps = 200
# 17:04:01 [INFO] train episode 22: reward = -1432.05, steps = 200
# 17:04:02 [INFO] train episode 23: reward = -1358.36, steps = 200
# 17:04:04 [INFO] train episode 24: reward = -982.03, steps = 200
# 17:04:05 [INFO] train episode 25: reward = -1088.45, steps = 200
# 17:04:06 [INFO] train episode 26: reward = -1389.31, steps = 200
# 17:04:08 [INFO] train episode 27: reward = -1243.24, steps = 200
# 17:04:09 [INFO] train episode 28: reward = -1242.43, steps = 200
# 17:04:10 [INFO] train episode 29: reward = -1484.55, steps = 200
# 17:04:12 [INFO] train episode 30: reward = -1557.95, steps = 200
# 17:04:13 [INFO] train episode 31: reward = -1454.03, steps = 200
# 17:04:14 [INFO] train episode 32: reward = -1351.89, steps = 200
# 17:04:16 [INFO] train episode 33: reward = -767.52, steps = 200
# 17:04:17 [INFO] train episode 34: reward = -929.41, steps = 200
# 17:04:19 [INFO] train episode 35: reward = -674.23, steps = 200
# 17:04:20 [INFO] train episode 36: reward = -775.45, steps = 200
# 17:04:22 [INFO] train episode 37: reward = -756.23, steps = 200
# 17:04:23 [INFO] train episode 38: reward = -384.19, steps = 200
# 17:04:25 [INFO] train episode 39: reward = -378.14, steps = 200
# 17:04:27 [INFO] train episode 40: reward = -511.62, steps = 200
# 17:04:29 [INFO] train episode 41: reward = -497.89, steps = 200
# 17:04:30 [INFO] train episode 42: reward = -398.26, steps = 200
# 17:04:32 [INFO] train episode 43: reward = -512.86, steps = 200
# 17:04:34 [INFO] train episode 44: reward = -498.49, steps = 200
# 17:04:36 [INFO] train episode 45: reward = -386.12, steps = 200
# 17:04:38 [INFO] train episode 46: reward = -530.83, steps = 200
# 17:04:39 [INFO] train episode 47: reward = -380.15, steps = 200
# 17:04:41 [INFO] train episode 48: reward = -385.98, steps = 200
# 17:04:42 [INFO] train episode 49: reward = -261.34, steps = 200
# 17:04:43 [INFO] train episode 50: reward = -252.08, steps = 200
# 17:04:45 [INFO] train episode 51: reward = -542.07, steps = 200
# 17:04:46 [INFO] train episode 52: reward = -513.09, steps = 200
# 17:04:47 [INFO] train episode 53: reward = -531.63, steps = 200
# 17:04:49 [INFO] train episode 54: reward = -376.13, steps = 200
# 17:04:50 [INFO] train episode 55: reward = -373.22, steps = 200
# 17:04:51 [INFO] train episode 56: reward = -382.38, steps = 200
# 17:04:53 [INFO] train episode 57: reward = -262.19, steps = 200
# 17:04:54 [INFO] train episode 58: reward = -381.04, steps = 200
# 17:04:55 [INFO] train episode 59: reward = -384.18, steps = 200
# 17:04:57 [INFO] train episode 60: reward = -383.71, steps = 200
# 17:04:58 [INFO] train episode 61: reward = -364.98, steps = 200
# 17:04:59 [INFO] train episode 62: reward = -382.19, steps = 200
# 17:05:01 [INFO] train episode 63: reward = -265.31, steps = 200
# 17:05:02 [INFO] train episode 64: reward = -492.73, steps = 200
# 17:05:03 [INFO] train episode 65: reward = -482.02, steps = 200
# 17:05:04 [INFO] train episode 66: reward = -360.56, steps = 200
# 17:05:06 [INFO] train episode 67: reward = -378.57, steps = 200
# 17:05:07 [INFO] train episode 68: reward = -381.19, steps = 200
# 17:05:09 [INFO] train episode 69: reward = -464.45, steps = 200
# 17:05:10 [INFO] train episode 70: reward = -380.82, steps = 200
# 17:05:11 [INFO] train episode 71: reward = -305.35, steps = 200
# 17:05:13 [INFO] train episode 72: reward = -506.26, steps = 200
# 17:05:14 [INFO] train episode 73: reward = -500.04, steps = 200
# 17:05:15 [INFO] train episode 74: reward = -612.46, steps = 200
# 17:05:17 [INFO] train episode 75: reward = -369.55, steps = 200
# 17:05:18 [INFO] train episode 76: reward = -372.93, steps = 200
# 17:05:20 [INFO] train episode 77: reward = -386.82, steps = 200
# 17:05:21 [INFO] train episode 78: reward = -384.22, steps = 200
# 17:05:22 [INFO] train episode 79: reward = -519.46, steps = 200
# 17:05:24 [INFO] train episode 80: reward = -439.77, steps = 200
# 17:05:25 [INFO] train episode 81: reward = -382.64, steps = 200
# 17:05:27 [INFO] train episode 82: reward = -592.49, steps = 200
# 17:05:28 [INFO] train episode 83: reward = -433.28, steps = 200
# 17:05:29 [INFO] train episode 84: reward = -247.33, steps = 200
# 17:05:31 [INFO] train episode 85: reward = -611.18, steps = 200
# 17:05:32 [INFO] train episode 86: reward = -432.38, steps = 200
# 17:05:34 [INFO] train episode 87: reward = -384.62, steps = 200
# 17:05:35 [INFO] train episode 88: reward = -383.57, steps = 200
# 17:05:36 [INFO] train episode 89: reward = -442.47, steps = 200
# 17:05:38 [INFO] train episode 90: reward = -407.02, steps = 200
# 17:05:39 [INFO] train episode 91: reward = -391.40, steps = 200
# 17:05:41 [INFO] train episode 92: reward = -388.82, steps = 200
# 17:05:42 [INFO] train episode 93: reward = -514.68, steps = 200
# 17:05:44 [INFO] train episode 94: reward = -250.88, steps = 200
# 17:05:45 [INFO] train episode 95: reward = -260.83, steps = 200
# 17:05:46 [INFO] train episode 96: reward = -248.92, steps = 200
# 17:05:48 [INFO] train episode 97: reward = -258.46, steps = 200
# 17:05:49 [INFO] train episode 98: reward = -358.67, steps = 200
# 17:05:51 [INFO] train episode 99: reward = -218.57, steps = 200
# 17:05:52 [INFO] train episode 100: reward = -376.86, steps = 200
# 17:05:54 [INFO] train episode 101: reward = -503.17, steps = 200
# 17:05:55 [INFO] train episode 102: reward = -377.82, steps = 200
# 17:05:56 [INFO] train episode 103: reward = -253.20, steps = 200
# 17:05:58 [INFO] train episode 104: reward = -323.03, steps = 200
# 17:05:59 [INFO] train episode 105: reward = -383.87, steps = 200
# 17:06:01 [INFO] train episode 106: reward = -346.73, steps = 200
# 17:06:02 [INFO] train episode 107: reward = -266.31, steps = 200
# 17:06:03 [INFO] train episode 108: reward = -363.42, steps = 200
# 17:06:05 [INFO] train episode 109: reward = -491.60, steps = 200
# 17:06:06 [INFO] train episode 110: reward = -486.34, steps = 200
# 17:06:07 [INFO] train episode 111: reward = -499.58, steps = 200
# 17:06:08 [INFO] train episode 112: reward = -504.36, steps = 200
# 17:06:10 [INFO] train episode 113: reward = -487.71, steps = 200
# 17:06:11 [INFO] train episode 114: reward = -505.58, steps = 200
# 17:06:12 [INFO] train episode 115: reward = -380.43, steps = 200
# 17:06:14 [INFO] train episode 116: reward = -385.47, steps = 200
# 17:06:15 [INFO] train episode 117: reward = -510.79, steps = 200
# 17:06:16 [INFO] train episode 118: reward = -487.97, steps = 200
# 17:06:18 [INFO] train episode 119: reward = -613.96, steps = 200
# 17:06:19 [INFO] train episode 120: reward = -509.80, steps = 200
# 17:06:20 [INFO] train episode 121: reward = -511.53, steps = 200
# 17:06:22 [INFO] train episode 122: reward = -513.49, steps = 200
# 17:06:23 [INFO] train episode 123: reward = -511.23, steps = 200
# 17:06:24 [INFO] train episode 124: reward = -520.02, steps = 200
# 17:06:25 [INFO] train episode 125: reward = -621.24, steps = 200
# 17:06:27 [INFO] train episode 126: reward = -716.38, steps = 200
# 17:06:28 [INFO] train episode 127: reward = -615.79, steps = 200
# 17:06:29 [INFO] train episode 128: reward = -513.08, steps = 200
# 17:06:31 [INFO] train episode 129: reward = -555.35, steps = 200
# 17:06:32 [INFO] train episode 130: reward = -517.87, steps = 200
# 17:06:33 [INFO] train episode 131: reward = -512.59, steps = 200
# 17:06:35 [INFO] train episode 132: reward = -608.30, steps = 200
# 17:06:36 [INFO] train episode 133: reward = -630.69, steps = 200
# 17:06:37 [INFO] train episode 134: reward = -624.30, steps = 200
# 17:06:38 [INFO] train episode 135: reward = -379.66, steps = 200
# 17:06:40 [INFO] train episode 136: reward = -495.01, steps = 200
# 17:06:41 [INFO] train episode 137: reward = -505.98, steps = 200
# 17:06:42 [INFO] train episode 138: reward = -384.94, steps = 200
# 17:06:44 [INFO] train episode 139: reward = -388.53, steps = 200
# 17:06:45 [INFO] train episode 140: reward = -389.06, steps = 200
# 17:06:46 [INFO] train episode 141: reward = -374.65, steps = 200
# 17:06:48 [INFO] train episode 142: reward = -482.93, steps = 200
# 17:06:49 [INFO] train episode 143: reward = -390.74, steps = 200
# 17:06:50 [INFO] train episode 144: reward = -379.95, steps = 200
# 17:06:52 [INFO] train episode 145: reward = -271.67, steps = 200
# 17:06:53 [INFO] train episode 146: reward = -380.36, steps = 200
# 17:06:54 [INFO] train episode 147: reward = -481.82, steps = 200
# 17:06:56 [INFO] train episode 148: reward = -263.78, steps = 200
# 17:06:57 [INFO] train episode 149: reward = -459.92, steps = 200
# 17:06:58 [INFO] train episode 150: reward = -470.67, steps = 200
# 17:07:00 [INFO] train episode 151: reward = -1.64, steps = 200
# 17:07:01 [INFO] train episode 152: reward = -122.51, steps = 200
# 17:07:03 [INFO] train episode 153: reward = -240.55, steps = 200
# 17:07:04 [INFO] train episode 154: reward = -129.08, steps = 200
# 17:07:05 [INFO] train episode 155: reward = -133.79, steps = 200
# 17:07:07 [INFO] train episode 156: reward = -242.94, steps = 200
# 17:07:08 [INFO] train episode 157: reward = -133.32, steps = 200
# 17:07:09 [INFO] train episode 158: reward = -235.67, steps = 200
# 17:07:11 [INFO] train episode 159: reward = -121.00, steps = 200
# 17:07:13 [INFO] train episode 160: reward = -10.15, steps = 200
# 17:07:14 [INFO] train episode 161: reward = -5.34, steps = 200
# 17:07:16 [INFO] train episode 162: reward = -235.64, steps = 200
# 17:07:17 [INFO] train episode 163: reward = -126.78, steps = 200
# 17:07:19 [INFO] train episode 164: reward = -237.00, steps = 200
# 17:07:20 [INFO] train episode 165: reward = -8.67, steps = 200
# 17:07:22 [INFO] train episode 166: reward = -128.20, steps = 200
# 17:07:23 [INFO] train episode 167: reward = -248.34, steps = 200
# 17:07:24 [INFO] train episode 168: reward = -130.24, steps = 200
# 17:07:26 [INFO] train episode 169: reward = -10.00, steps = 200
# 17:07:26 [INFO] ==== test ====
# 17:07:26 [INFO] test episode 0: reward = -9.27, steps = 200
# 17:07:26 [INFO] test episode 1: reward = -122.81, steps = 200
# 17:07:26 [INFO] test episode 2: reward = -123.13, steps = 200
# 17:07:26 [INFO] test episode 3: reward = -132.37, steps = 200
# 17:07:26 [INFO] test episode 4: reward = -254.18, steps = 200
# 17:07:26 [INFO] test episode 5: reward = -9.36, steps = 200
# 17:07:26 [INFO] test episode 6: reward = -137.44, steps = 200
# 17:07:26 [INFO] test episode 7: reward = -245.72, steps = 200
# 17:07:26 [INFO] test episode 8: reward = -241.94, steps = 200
# 17:07:26 [INFO] test episode 9: reward = -260.14, steps = 200
# 17:07:26 [INFO] test episode 10: reward = -138.02, steps = 200
# 17:07:26 [INFO] test episode 11: reward = -125.75, steps = 200
# 17:07:26 [INFO] test episode 12: reward = -127.29, steps = 200
# 17:07:26 [INFO] test episode 13: reward = -128.26, steps = 200
# 17:07:26 [INFO] test episode 14: reward = -127.48, steps = 200
# 17:07:26 [INFO] test episode 15: reward = -136.46, steps = 200
# 17:07:27 [INFO] test episode 16: reward = -254.26, steps = 200
# 17:07:27 [INFO] test episode 17: reward = -131.51, steps = 200
# 17:07:27 [INFO] test episode 18: reward = -122.45, steps = 200
# 17:07:27 [INFO] test episode 19: reward = -264.39, steps = 200
# 17:07:27 [INFO] test episode 20: reward = -136.46, steps = 200
# 17:07:27 [INFO] test episode 21: reward = -138.88, steps = 200
# 17:07:27 [INFO] test episode 22: reward = -133.21, steps = 200
# 17:07:27 [INFO] test episode 23: reward = -124.25, steps = 200
# 17:07:27 [INFO] test episode 24: reward = -130.58, steps = 200
# 17:07:27 [INFO] test episode 25: reward = -139.69, steps = 200
# 17:07:27 [INFO] test episode 26: reward = -131.31, steps = 200
# 17:07:27 [INFO] test episode 27: reward = -244.40, steps = 200
# 17:07:27 [INFO] test episode 28: reward = -128.92, steps = 200
# 17:07:27 [INFO] test episode 29: reward = -248.97, steps = 200
# 17:07:27 [INFO] test episode 30: reward = -260.86, steps = 200
# 17:07:27 [INFO] test episode 31: reward = -133.95, steps = 200
# 17:07:27 [INFO] test episode 32: reward = -124.09, steps = 200
# 17:07:27 [INFO] test episode 33: reward = -134.66, steps = 200
# 17:07:27 [INFO] test episode 34: reward = -9.74, steps = 200
# 17:07:27 [INFO] test episode 35: reward = -130.13, steps = 200
# 17:07:27 [INFO] test episode 36: reward = -135.55, steps = 200
# 17:07:27 [INFO] test episode 37: reward = -243.34, steps = 200
# 17:07:27 [INFO] test episode 38: reward = -134.51, steps = 200
# 17:07:27 [INFO] test episode 39: reward = -252.96, steps = 200
# 17:07:27 [INFO] test episode 40: reward = -247.51, steps = 200
# 17:07:27 [INFO] test episode 41: reward = -132.12, steps = 200
# 17:07:27 [INFO] test episode 42: reward = -234.93, steps = 200
# 17:07:28 [INFO] test episode 43: reward = -130.45, steps = 200
# 17:07:28 [INFO] test episode 44: reward = -135.20, steps = 200
# 17:07:28 [INFO] test episode 45: reward = -126.01, steps = 200
# 17:07:28 [INFO] test episode 46: reward = -130.80, steps = 200
# 17:07:28 [INFO] test episode 47: reward = -9.14, steps = 200
# 17:07:28 [INFO] test episode 48: reward = -138.83, steps = 200
# 17:07:28 [INFO] test episode 49: reward = -242.37, steps = 200
# 17:07:28 [INFO] test episode 50: reward = -132.21, steps = 200
# 17:07:28 [INFO] test episode 51: reward = -123.81, steps = 200
# 17:07:28 [INFO] test episode 52: reward = -249.20, steps = 200
# 17:07:28 [INFO] test episode 53: reward = -258.39, steps = 200
# 17:07:28 [INFO] test episode 54: reward = -259.92, steps = 200
# 17:07:28 [INFO] test episode 55: reward = -135.45, steps = 200
# 17:07:28 [INFO] test episode 56: reward = -348.91, steps = 200
# 17:07:28 [INFO] test episode 57: reward = -135.02, steps = 200
# 17:07:28 [INFO] test episode 58: reward = -132.36, steps = 200
# 17:07:28 [INFO] test episode 59: reward = -253.18, steps = 200
# 17:07:28 [INFO] test episode 60: reward = -137.41, steps = 200
# 17:07:28 [INFO] test episode 61: reward = -122.85, steps = 200
# 17:07:28 [INFO] test episode 62: reward = -132.34, steps = 200
# 17:07:28 [INFO] test episode 63: reward = -9.36, steps = 200
# 17:07:28 [INFO] test episode 64: reward = -8.91, steps = 200
# 17:07:28 [INFO] test episode 65: reward = -303.70, steps = 200
# 17:07:28 [INFO] test episode 66: reward = -124.39, steps = 200
# 17:07:28 [INFO] test episode 67: reward = -239.64, steps = 200
# 17:07:28 [INFO] test episode 68: reward = -10.06, steps = 200
# 17:07:28 [INFO] test episode 69: reward = -131.18, steps = 200
# 17:07:29 [INFO] test episode 70: reward = -140.71, steps = 200
# 17:07:29 [INFO] test episode 71: reward = -126.80, steps = 200
# 17:07:29 [INFO] test episode 72: reward = -126.99, steps = 200
# 17:07:29 [INFO] test episode 73: reward = -9.43, steps = 200
# 17:07:29 [INFO] test episode 74: reward = -9.75, steps = 200
# 17:07:29 [INFO] test episode 75: reward = -251.33, steps = 200
# 17:07:29 [INFO] test episode 76: reward = -132.98, steps = 200
# 17:07:29 [INFO] test episode 77: reward = -8.98, steps = 200
# 17:07:29 [INFO] test episode 78: reward = -131.10, steps = 200
# 17:07:29 [INFO] test episode 79: reward = -124.52, steps = 200
# 17:07:29 [INFO] test episode 80: reward = -124.05, steps = 200
# 17:07:29 [INFO] test episode 81: reward = -135.32, steps = 200
# 17:07:29 [INFO] test episode 82: reward = -121.53, steps = 200
# 17:07:29 [INFO] test episode 83: reward = -127.39, steps = 200
# 17:07:29 [INFO] test episode 84: reward = -326.79, steps = 200
# 17:07:29 [INFO] test episode 85: reward = -257.31, steps = 200
# 17:07:29 [INFO] test episode 86: reward = -135.07, steps = 200
# 17:07:29 [INFO] test episode 87: reward = -129.41, steps = 200
# 17:07:29 [INFO] test episode 88: reward = -246.56, steps = 200
# 17:07:29 [INFO] test episode 89: reward = -251.62, steps = 200
# 17:07:29 [INFO] test episode 90: reward = -133.79, steps = 200
# 17:07:29 [INFO] test episode 91: reward = -140.91, steps = 200
# 17:07:29 [INFO] test episode 92: reward = -9.66, steps = 200
# 17:07:29 [INFO] test episode 93: reward = -127.59, steps = 200
# 17:07:29 [INFO] test episode 94: reward = -123.88, steps = 200
# 17:07:29 [INFO] test episode 95: reward = -122.24, steps = 200
# 17:07:29 [INFO] test episode 96: reward = -137.22, steps = 200
# 17:07:29 [INFO] test episode 97: reward = -127.52, steps = 200
# 17:07:29 [INFO] test episode 98: reward = -129.07, steps = 200
# 17:07:30 [INFO] test episode 99: reward = -134.71, steps = 200
# 17:07:30 [INFO] average episode reward = -150.89 ± 75.53

# %%
env.close()
